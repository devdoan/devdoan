# %% [markdown]
# <a href="https://colab.research.google.com/github/devdoan/devdoan/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("blastchar/telco-customer-churn")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'telco-customer-churn' dataset.
# Path to dataset files: /kaggle/input/telco-customer-churn

# %% [markdown]
# ## Tải lên bộ dữ liệu để bắt đầu xử lý

# %%
import pandas as pd

csv_file_path = f"{path}/WA_Fn-UseC_-Telco-Customer-Churn.csv"
df = pd.read_csv(csv_file_path)

raw_df = df.copy()

display(df.head())
df.shape
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %% [markdown]
# Đây là giải thích ý nghĩa của từng cột trong bộ dữ liệu:
#
# - customerID: ID duy nhất cho mỗi khách hàng.
# - gender: Giới tính của khách hàng (Nam hoặc Nữ).
# - SeniorCitizen: Cho biết khách hàng có phải là công dân cao tuổi hay không (1 cho Có, 0 cho Không).
# - Partner: Cho biết khách hàng có bạn đời hay không (Yes hoặc No).
# - Dependents: Cho biết khách hàng có người phụ thuộc hay không (Yes hoặc No).
# - tenure: Số tháng khách hàng ở lại với công ty.
# - PhoneService: Cho biết khách hàng có dịch vụ điện thoại hay không (Yes hoặc No).
# - MultipleLines: Cho biết khách hàng có nhiều đường dây điện thoại hay không (Yes, No hoặc No phone service).
# - InternetService: Nhà cung cấp dịch vụ internet của khách hàng (DSL, Fiber optic, hoặc No).
# - OnlineSecurity: Cho biết khách hàng có dịch vụ bảo mật trực tuyến hay không (Yes, No, hoặc No internet service).
# - OnlineBackup: Cho biết khách hàng có dịch vụ sao lưu trực tuyến hay không (Yes, No, hoặc No internet service).
# - DeviceProtection: Cho biết khách hàng có dịch vụ bảo vệ thiết bị hay không (Yes, No, hoặc No internet service).
# - TechSupport: Cho biết khách hàng có dịch vụ hỗ trợ kỹ thuật hay không (Yes, No, hoặc No internet service).
# StreamingTV: Cho biết khách hàng có dịch vụ truyền hình trực tuyến hay không (Yes, No, hoặc No internet service).
# - StreamingMovies: Cho biết khách hàng có dịch vụ xem phim trực tuyến hay không (Yes, No, hoặc No internet service).
# - Contract: Loại hợp đồng của khách hàng (Month-to-month, One year, Two year).
# - PaperlessBilling: Cho biết khách hàng có sử dụng hình thức thanh toán không giấy tờ hay không (Yes hoặc No).
# - PaymentMethod: Phương thức thanh toán của khách hàng (Electronic check, Mailed check, Bank transfer (automatic), Credit card (automatic)).
# - MonthlyCharges: Số tiền khách hàng phải trả hàng tháng.
# - TotalCharges: Tổng số tiền khách hàng đã trả.
# - Churn: Cho biết khách hàng có rời bỏ dịch vụ hay không (Yes hoặc No). Đây là biến mục tiêu.

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
# ## Kiểm ta dữ liệu thiếu qua đồ thị

# %%
import missingno as msno
msno.matrix(df)
# Out:
# <Axes: >

# %%
df = df.drop(['customerID'], axis = 1)

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %% [markdown]
# ## Kiểm tra xem có ô dữ liệu nào bị thiếu không vì có thể nó có dạng string trắng

# %%
for col in df.select_dtypes(include='object').columns:
    if (df[col].astype(str).str.strip() == '').any():
        print(f"Column '{col}' contains blank spaces or empty strings.")
        # Optionally display rows with blank spaces in this column
        # display(df[df[col].astype(str).str.strip() == ''])
# Out:
# Column 'TotalCharges' contains blank spaces or empty strings.

# %%
blank_spaces_count = df[df['TotalCharges'].astype(str).str.strip() == ''].shape[0]
print(f"Number of blank spaces or empty strings in 'TotalCharges' column: {blank_spaces_count}")
# Out:
# Number of blank spaces or empty strings in 'TotalCharges' column: 11

# %%
df['TotalCharges'] = pd.to_numeric(df.TotalCharges, errors='coerce')
df.isnull().sum()
# Out:
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %% [markdown]
# ## Gán NaN cho các ô trắng

# %%
import numpy as np
df[np.isnan(df['TotalCharges'])]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

plt.figure(figsize=(10, 6))

# Plot all data points with some transparency
sns.scatterplot(data=df.dropna(subset=['TotalCharges']), x='tenure', y='TotalCharges', alpha=0.7, label='Valid TotalCharges')

# Filter for rows where TotalCharges is NaN
nan_totalcharges_df = df[np.isnan(df['TotalCharges'])]

# Plot the points with NaN TotalCharges (they will have tenure = 0)
sns.scatterplot(data=nan_totalcharges_df, x='tenure', y='MonthlyCharges', color='red', s=50, label='TotalCharges is NaN (using MonthlyCharges for y-axis)')


plt.title('Relationship between Tenure and TotalCharges (NaN values highlighted)')
plt.xlabel('Tenure (months)')
plt.ylabel('TotalCharges')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## Cần kiểm tra thêm là có khách nào tenure bằng không nữa không

# %%
df[df['tenure'] == 0].index
# Out:
# Index([488, 753, 936, 1082, 1340, 3331, 3826, 4380, 5218, 6670, 6754], dtype='int64')

# %%
tenure_zero_count = df[df['tenure'] == 0].shape[0]
print(f"Number of customers with tenure equal to 0: {tenure_zero_count}")
# Out:
# Number of customers with tenure equal to 0: 11

# %% [markdown]
# # Loại bỏ các hàng chứa NaN này vì chúng khá nhỏ trong tập dữ liệu

# %%
df.drop(labels=df[df['tenure'] == 0].index, axis=0, inplace=True)

# %%
tenure_zero_count = df[df['tenure'] == 0].shape[0]
print(f"Number of customers with tenure equal to 0: {tenure_zero_count}")
# Out:
# Number of customers with tenure equal to 0: 0

# %%
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# # Trong tương lai cần nghiên cứu thêm:
# - Thống kê tóm tắt và phân phối dữ liệu: Tính toán các thống kê tóm tắt cho các cột số và trực quan hóa phân phối của các đặc trưng chính (số và phân loại).
# - Phân tích các Đặc trưng phân loại: Kiểm tra phân phối của các đặc trưng phân loại và mối quan hệ của chúng với biến mục tiêu ('Churn').
# - Phân tích các Đặc trưng số: Khám phá phân phối của các đặc trưng số và mối quan hệ của chúng với 'Churn'.
# - Phân tích song biến: Nghiên cứu mối quan hệ giữa các cặp biến, đặc biệt là cách các đặc trưng khác nhau liên quan đến 'Churn'.
# - Kỹ thuật Đặc trưng (tùy chọn): Tạo các đặc trưng mới có thể hữu ích cho việc mô hình hóa dựa trên những hiểu biết thu được từ EDA.

# %% [markdown]
# ## Nghiên cứu biểu đồ

# %%
plt.figure(figsize=(6, 4))
ax = sns.countplot(data=df, x='Churn', hue='Churn', palette=['skyblue', 'salmon'], legend=False) # Use hue to apply palette correctly and suppress warning
plt.title('Distribution of Churn')
plt.xlabel('Churn')
plt.ylabel('Count')

# Add counts on top of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()

# %%
plt.figure(figsize=(6, 6))
labels =["Churn: Yes","Churn:No"]
values = [1869,5163]
labels_gender = ["F","M","F","M"]
sizes_gender = [939,930 , 2544,2619]
colors = ['#ff6666', '#66b3ff']
colors_gender = ['#c2c2f0','#ffb3e6', '#c2c2f0','#ffb3e6']
explode = (0.3,0.3)
explode_gender = (0.1,0.1,0.1,0.1)
textprops = {"fontsize":15}
#Plot
plt.pie(values, labels=labels,autopct='%1.1f%%',pctdistance=1.08, labeldistance=0.8,colors=colors, startangle=90,frame=True, explode=explode,radius=10, textprops =textprops, counterclock = True, )
plt.pie(sizes_gender,labels=labels_gender,colors=colors_gender,startangle=90, explode=explode_gender,radius=7, textprops =textprops, counterclock = True, )
#Draw circle
centre_circle = plt.Circle((0,0),5,color='black', fc='white',linewidth=0)
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.title('Churn Distribution w.r.t Gender: Male(M), Female(F)', fontsize=15, y=1.1)

# show plot

plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='SeniorCitizen', hue='Churn', palette='pastel') # Added palette='pastel'
plt.title('Relationship between SeniorCitizen and Churn')
plt.xlabel('SeniorCitizen')
plt.ylabel('Count')
plt.xticks([0, 1], ['No', 'Yes']) # Label the x-axis ticks
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
ax = sns.countplot(data=df, x='InternetService', hue='Churn', palette='viridis')
plt.title('Relationship between InternetService and Churn')
plt.xlabel('Internet Service Type')
plt.ylabel('Count')

# Add counts on top of the bars
for p in ax.patches:
    height = p.get_height()
    # Thêm điều kiện kiểm tra chiều cao của cột ở đây
    if height > 0:
        ax.annotate(f'{int(height)}', (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()

# %%
df["InternetService"].describe(include=['object', 'bool'])
# Out:
# count            7032
# unique              3
# top       Fiber optic
# freq             3096
# Name: InternetService, dtype: object

# %%
fiber_optic_customers = df[df['InternetService'] == 'Fiber optic']

churn_rate_fiber_optic = fiber_optic_customers['Churn'].value_counts(normalize=True)

print("Tỷ lệ churn rate cho khách hàng Fiber optic:")
print(churn_rate_fiber_optic)
# Out:
# Tỷ lệ churn rate cho khách hàng Fiber optic:
# Churn
# No     0.581072
# Yes    0.418928
# Name: proportion, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
ax = sns.countplot(data=df, x='Contract', hue='Churn', palette='plasma')
plt.title('Relationship between Contract Type and Churn')
plt.xlabel('Contract Type')
plt.ylabel('Count')

# Add counts on top of the bars
for p in ax.patches:
    height = p.get_height()
    # Thêm điều kiện kiểm tra chiều cao của cột ở đây
    if height > 0:
        ax.annotate(f'{int(height)}', (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()

# %%
month_to_month_customers = df[df['Contract'] == 'Month-to-month']

churn_rate_month_to_month = month_to_month_customers['Churn'].value_counts(normalize=True)

print("Tỷ lệ churn rate cho khách hàng có hợp đồng Month-to-month:")
print(churn_rate_month_to_month)
# Out:
# Tỷ lệ churn rate cho khách hàng có hợp đồng Month-to-month:
# Churn
# No     0.572903
# Yes    0.427097
# Name: proportion, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Use catplot to create separate plots for each gender
sns.catplot(data=df, x='Contract', hue='Churn', col='gender', kind='count', palette='plasma', height=5, aspect=.8) # Changed palette to 'plasma'

plt.suptitle('Relationship between Contract Type, Churn, and Gender', y=1.02) # Add a main title
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6)) # Increase figure size for better readability of PaymentMethod labels
ax = sns.countplot(data=df, x='PaymentMethod', hue='Churn', palette='magma') # Assign the plot to an axes object
plt.title('Relationship between Payment Method and Churn')
plt.xlabel('Payment Method')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for better readability

# Add counts on top of the bars
for p in ax.patches:
    height = p.get_height()
    # Thêm điều kiện kiểm tra chiều cao của cột ở đây
    if height > 0:
        ax.annotate(f'{int(height)}', (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.tight_layout() # Adjust layout to prevent labels overlapping
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 7))
sns.violinplot(data=df, x='Churn', y='MonthlyCharges', hue='PaymentMethod', split=True, palette='pastel')
plt.title('Distribution of MonthlyCharges by Churn and Payment Method')
plt.xlabel('Churn')
plt.ylabel('Monthly Charges')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='MonthlyCharges', y='tenure', hue='Churn', palette=['green', 'red'], alpha=0.7) # Changed x and y axes
plt.title('Monthly Charges vs Tenure colored by Churn') # Updated title
plt.xlabel('Monthly Charges') # Updated x-axis label
plt.ylabel('Tenure') # Updated y-axis label
plt.grid(True)
plt.show()

# %%
import plotly.express as px

fig = px.violin(df,
                x='Churn',
                y='tenure',
                color='Churn',
                box=True,
                points=False,
                template='plotly_white',
                color_discrete_map={'No':'#1f77b4', 'Yes':'#e74c3c'}
               )

fig.update_layout(

    width=1000,
    height=500,
    # ---------------------------------------------
    title_text='<b>Distribution of Customer Tenure by Churn Status</b>',
    title_font_size=22,
    xaxis_title='Churn Status',
    yaxis_title='Tenure (in Months)',
    legend_title='Churn',
    font=dict(
        family="Arial, sans-serif",
        size=12,
        color="Black"
    ),
    violingap=0.1
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Assume df is already loaded
# import pandas as pd
# df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')

# Set up the plot style and figure size
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")

# Create the plot with a single, powerful command
sns.kdeplot(data=df, x='MonthlyCharges', hue='Churn',
            fill=True, common_norm=False, palette={'No':'#3498db', 'Yes':'#e74c3c'})

# Customize labels and title in English
plt.title('Distribution of Monthly Charges by Churn', fontsize=16)
plt.xlabel('Monthly Charges', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.legend(title='Churn', labels=['Yes', 'No'])

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Assume df is already loaded and 'TotalCharges' has been cleaned
# import pandas as pd
# df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')
# df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
# df['TotalCharges'].fillna(0, inplace=True)

# Set up the plot style and figure size
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")

# Create the plot using a single, optimized command
sns.kdeplot(data=df, x='TotalCharges', hue='Churn',
            fill=True, common_norm=False, palette={'No':'green', 'Yes':'#e74c3c'})

# Customize labels and title in English
plt.title('Distribution of Total Charges by Churn', fontsize=16)
plt.xlabel('Total Charges', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.legend(title='Churn', labels=['Yes', 'No'])

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
ax = sns.countplot(data=df, x='Dependents', hue='Churn', palette='viridis')
plt.title('Relationship between Dependents and Churn')
plt.xlabel('Dependents')
plt.ylabel('Count')

# Add counts on top of the bars
for p in ax.patches:
    height = p.get_height()
    # Thêm điều kiện kiểm tra chiều cao của cột ở đây
    if height > 0:
        ax.annotate(f'{int(height)}', (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
ax = sns.countplot(data=df, x='Partner', hue='Churn', palette='viridis')
plt.title('Relationship between Partner and Churn')
plt.xlabel('Partner')
plt.ylabel('Count')

# Add counts on top of the bars
for p in ax.patches:
    height = p.get_height()
    # Thêm điều kiện kiểm tra chiều cao của cột ở đây
    if height > 0:
        ax.annotate(f'{int(height)}', (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
ax = sns.countplot(data=df, x='OnlineSecurity', hue='Churn', palette='viridis')
plt.title('Relationship between Online Security and Churn')
plt.xlabel('Online Security')
plt.ylabel('Count')

# Add counts on top of the bars
for p in ax.patches:
    height = p.get_height()
    # Thêm điều kiện kiểm tra chiều cao của cột ở đây
    if height > 0:
        ax.annotate(f'{int(height)}', (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

color_map = {"Yes": '#FFA15A', "No": '#00CC96'}

plt.figure(figsize=(6, 4))
ax = sns.countplot(data=df, x='PaperlessBilling', hue='Churn', palette=color_map)
plt.title('Relationship between Paperless Billing and Churn')
plt.xlabel('Paperless Billing')
plt.ylabel('Count')

# Add counts on top of the bars
for p in ax.patches:
    height = p.get_height()
    # Thêm điều kiện kiểm tra chiều cao của cột ở đây
    if height > 0:
        ax.annotate(f'{int(height)}', (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
ax = sns.countplot(data=df, x='TechSupport', hue='Churn', palette='viridis')
plt.title('Relationship between Tech Support and Churn')
plt.xlabel('Tech Support')
plt.ylabel('Count')

# Add counts on top of the bars
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{int(height)}', (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

color_map = {"Yes": '#00CC96', "No": '#B6E880'}

plt.figure(figsize=(6, 4))
ax = sns.countplot(data=df, x='PhoneService', hue='Churn', palette=color_map)
plt.title('Relationship between Phone Service and Churn')
plt.xlabel('Phone Service')
plt.ylabel('Count')

# Add counts on top of the bars
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{int(height)}', (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()

# %%
plt.figure(figsize=(8, 5))
ax = sns.countplot(data=df, x='MultipleLines', hue='Churn', palette='viridis')
plt.title('Relationship between MultipleLines and Churn')
plt.xlabel('Multiple Lines')
plt.ylabel('Count')

# Add counts on top of the bars
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{int(height)}', (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()

# %%
plt.figure(figsize=(8, 5))
ax = sns.countplot(data=df, x='OnlineBackup', hue='Churn', palette='viridis')
plt.title('Relationship between Online Backup and Churn')
plt.xlabel('Online Backup')
plt.ylabel('Count')

# Add counts on top of the bars
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{int(height)}', (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()

# %%
plt.figure(figsize=(8, 5))
ax = sns.countplot(data=df, x='DeviceProtection', hue='Churn', palette='viridis')
plt.title('Relationship between Device Protection and Churn')
plt.xlabel('Device Protection')
plt.ylabel('Count')

# Add counts on top of the bars
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{int(height)}', (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='center', xytext=(0, 5), textcoords='offset points')
plt.show()

# %%
plt.figure(figsize=(8, 5))
ax = sns.countplot(data=df, x='StreamingTV', hue='Churn', palette='viridis')
plt.title('Relationship between Streaming TV and Churn')
plt.xlabel('Streaming TV')
plt.ylabel('Count')

# Add counts on top of the bars
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{int(height)}', (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()

# %%
plt.figure(figsize=(8, 5))
ax = sns.countplot(data=df, x='StreamingMovies', hue='Churn', palette='viridis')
plt.title('Relationship between Streaming Movies and Churn')
plt.xlabel('Streaming Movies')
plt.ylabel('Count')

# Add counts on top of the bars
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{int(height)}', (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()

# %%
numerical_cols = ['tenure', 'MonthlyCharges', 'TotalCharges']
df[numerical_cols].describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  7032.000000     7032.000000   7032.000000
# mean     32.421786       64.798208   2283.300441
# std      24.545260       30.085974   2266.771362
# min       1.000000       18.250000     18.800000
# 25%       9.000000       35.587500    401.450000
# 50%      29.000000       70.350000   1397.475000
# 75%      55.000000       89.862500   3794.737500
# max      72.000000      118.750000   8684.800000

# %%
plt.figure(figsize=(25, 10))

corr = df.apply(lambda x: pd.factorize(x)[0]).corr()

mask = np.triu(np.ones_like(corr, dtype=bool))

ax = sns.heatmap(corr, mask=mask, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, linewidths=.2, cmap='coolwarm', vmin=-1, vmax=1)

# %% [markdown]
# ## Xử lý dữ liệu

# %%
from sklearn.preprocessing import LabelEncoder

def object_to_int(dataframe_series):
    if dataframe_series.dtype=='object':
        dataframe_series = LabelEncoder().fit_transform(dataframe_series)
    return dataframe_series

# %%
df = df.apply(lambda x: object_to_int(x))
df.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             2
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
df.corr()['Churn'].sort_values(ascending = False)
# Out:
# Churn               1.000000
# MonthlyCharges      0.192858
# PaperlessBilling    0.191454
# SeniorCitizen       0.150541
# PaymentMethod       0.107852
# MultipleLines       0.038043
# PhoneService        0.011691
# gender             -0.008545
# StreamingTV        -0.036303
# StreamingMovies    -0.038802
# InternetService    -0.047097
# Partner            -0.149982
# Dependents         -0.163128
# DeviceProtection   -0.177883
# OnlineBackup       -0.195290
# TotalCharges       -0.199484
# TechSupport        -0.282232
# OnlineSecurity     -0.289050
# tenure             -0.354049
# Contract           -0.396150
# Name: Churn, dtype: float64

# %% [markdown]
# ### Dùng biểu đồ để xem mấy biến số này có cùng scale không

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Danh sách các cột cần vẽ
num_cols = ["tenure", 'MonthlyCharges', 'TotalCharges']

# 1. Tạo một figure lớn chứa 3 hàng, 1 cột cho các biểu đồ con
# figsize=(8, 12) -> rộng 8, cao 12 để có đủ không gian
fig, axes = plt.subplots(nrows=len(num_cols), ncols=1, figsize=(8, 12))

# Đặt một tiêu đề chung cho cả figure
fig.suptitle('Distribution of Numerical Features', fontsize=16)

# 2. Dùng vòng lặp để vẽ lần lượt vào từng subplot
for i, feat in enumerate(num_cols):
    sns.histplot(data=df, x=feat, color='royalblue', kde=True, stat='density', ax=axes[i])
    axes[i].set_title("Distribution for {}".format(feat))

# 3. Tự động điều chỉnh khoảng cách giữa các subplot cho đẹp mắt
plt.tight_layout()

# 4. Chỉ gọi plt.show() MỘT LẦN DUY NHẤT ở cuối cùng
plt.show()

# %% [markdown]
# ### Bắt đầu tạo tập dữ liệu huấn luyện

# %%
X = df.drop(columns = ['Churn'])
y = df['Churn'].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.30, random_state = 40, stratify=y)

# %% [markdown]
# ### Chuẩn hóa dữ liệu và vẽ lại biểu đồ

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

numerical_cols = ['tenure', 'MonthlyCharges', 'TotalCharges']

# Chuẩn hóa dữ liệu
df_std = pd.DataFrame(StandardScaler().fit_transform(df[numerical_cols].astype('float64')),
                      columns=numerical_cols)

# 1. Tạo một figure lớn chứa 3 hàng, 1 cột cho các biểu đồ con
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(8, 12))

# Đặt tiêu đề chung
fig.suptitle('Distribution of Standardized Numerical Features', fontsize=16)

# 2. Dùng vòng lặp để vẽ lần lượt vào từng subplot (axes)
for i, feat in enumerate(numerical_cols):
    sns.histplot(data=df_std, x=feat, color='c', kde=True, stat='density', ax=axes[i])
    axes[i].set_title("Distribution for {}".format(feat))

# 3. Tự động điều chỉnh khoảng cách cho đẹp mắt
plt.tight_layout()

# 4. Hiển thị toàn bộ figure MỘT LẦN DUY NHẤT
plt.show()
